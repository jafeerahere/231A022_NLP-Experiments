# %% [markdown]
# <a href="https://colab.research.google.com/github/jafeerahere/231A022_NLP-Experiments/blob/main/AIDS_SEM7_NLP_EXPERIMENT06_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import UnigramTagger , BigramTagger , pos_tag
from nltk.corpus import treebank

# %%
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
nltk.download('treebank')
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.
# True

# %%
sample_text = "Today is a beautiful day. We will go to the beach and play volleyball."
tokens = word_tokenize(sample_text)

# %%
rule_based_tags = pos_tag(tokens)

print(rule_based_tags)
# Out:
# [('Today', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('day', 'NN'), ('.', '.'), ('We', 'PRP'), ('will', 'MD'), ('go', 'VB'), ('to', 'TO'), ('the', 'DT'), ('beach', 'NN'), ('and', 'CC'), ('play', 'VB'), ('volleyball', 'NN'), ('.', '.')]

# %%
nltk.help.upenn_tagset("DT")
# Out:
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those

# %%
train_sents = treebank.tagged_sents()[:30000]

unigram_tagger = UnigramTagger(train_sents)
unigram_tags = unigram_tagger.tag(tokens)

bigram_tagger = BigramTagger(train_sents, backoff=unigram_tagger)
bigram_tags = bigram_tagger.tag(tokens)

print("Unigram tagging:",unigram_tags)
print("\nBigram tagging:",bigram_tags)
# Out:
# Unigram tagging: [('Today', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('day', 'NN'), ('.', '.'), ('We', 'PRP'), ('will', 'MD'), ('go', 'VB'), ('to', 'TO'), ('the', 'DT'), ('beach', None), ('and', 'CC'), ('play', 'VB'), ('volleyball', None), ('.', '.')]
#
# Bigram tagging: [('Today', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('day', 'NN'), ('.', '.'), ('We', 'PRP'), ('will', 'MD'), ('go', 'VB'), ('to', 'TO'), ('the', 'DT'), ('beach', None), ('and', 'CC'), ('play', 'VB'), ('volleyball', None), ('.', '.')]

# %%
print("Original Sentence:", sample_text)
print("\nRule-based tagging (Statistical):")
print(rule_based_tags)
print("\nUnigram tagging:")
print(unigram_tags)
print("\nBigram tagging:")
print(bigram_tags)
# Out:
# Original Sentence: Today is a beautiful day. We will go to the beach and play volleyball.
#
# Rule-based tagging (Statistical):
# [('Today', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('day', 'NN'), ('.', '.'), ('We', 'PRP'), ('will', 'MD'), ('go', 'VB'), ('to', 'TO'), ('the', 'DT'), ('beach', 'NN'), ('and', 'CC'), ('play', 'VB'), ('volleyball', 'NN'), ('.', '.')]
#
# Unigram tagging:
# [('Today', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('day', 'NN'), ('.', '.'), ('We', 'PRP'), ('will', 'MD'), ('go', 'VB'), ('to', 'TO'), ('the', 'DT'), ('beach', None), ('and', 'CC'), ('play', 'VB'), ('volleyball', None), ('.', '.')]
#
# Bigram tagging:
# [('Today', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('day', 'NN'), ('.', '.'), ('We', 'PRP'), ('will', 'MD'), ('go', 'VB'), ('to', 'TO'), ('the', 'DT'), ('beach', None), ('and', 'CC'), ('play', 'VB'), ('volleyball', None), ('.', '.')]

# %%
corpus_size = len(treebank.tagged_sents())
split_idx = int(corpus_size * 0.9)
test_sents = treebank.tagged_sents()[split_idx:]

unigram_acc = unigram_tagger.evaluate(test_sents)
bigram_acc = bigram_tagger.evaluate(test_sents)

print(f"\nUnigram accuracy: {unigram_acc * 100:.2f}%")
print(f"\nBigram accuracy: {bigram_acc * 100:.2f}%")
# Out:
# /tmp/ipykernel_876/851629980.py:5: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   unigram_acc = unigram_tagger.evaluate(test_sents)
# /tmp/ipykernel_876/851629980.py:6: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   bigram_acc = bigram_tagger.evaluate(test_sents)
# Unigram accuracy: 96.00%
#
# Bigram accuracy: 98.64%
